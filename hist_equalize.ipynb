# %%
import cv2
import matplotlib.pyplot as plt
import helper.post_processing as pp
import helper.utils as ut
import matplotlib
from skimage import exposure

# Load the image
# image_path = r'C:\projects\DeepHeat\low-light\semidark-1-snap.png'
image_path = r'C:\projects\DeepHeat\low-light\gt-8-snap.png'
image = cv2.imread(image_path)
print(image.shape)
image = image[:, :int(image.shape[1]//2)]

# Check if the image was loaded properly
if image is None:
    raise ValueError("Image not found or unable to load image")

# print(image.shape)
# print(image.max(), image.min())

# Apply histogram equalization
# image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
# equalized_image = cv2.equalizeHist(image)
image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
clahe = cv2.createCLAHE(clipLimit=40, tileGridSize=(8, 8)) # clipLimit, tileGridSize
equalized_image = clahe.apply(image)
print(equalized_image.max(), equalized_image.min())
# image = image / 255
# equalized_image = exposure.equalize_hist(pp.process(image, [pp.white_balance, pp.clip,pp.gamma]))

# Display the original and equalized images
plt.figure(figsize=(20, 10))

# Original image
plt.subplot(1, 2, 1)
plt.title("Original Image")
plt.imshow(image, cmap='gray')
plt.axis('off')

# Equalized image
plt.subplot(1, 2, 2)
plt.title("Equalized Image")
plt.imshow(equalized_image, cmap='gray')
plt.axis('off')

plt.show()
# Out:
# (526, 1680, 3)
# 255 0

# %%
import cv2
import matplotlib.pyplot as plt
import helper.post_processing as pp
import helper.utils as ut
import matplotlib
from skimage import exposure

# Load the image
image_path = r'C:\projects\DeepHeat\low-light\semidark-8-snap.png'
# image_path = r'C:\projects\DeepHeat\low-light\gt-8-snap.png'
image = cv2.imread(image_path)
print(image.shape)
image = image[:, :int(image.shape[1]//2)]

# Check if the image was loaded properly
if image is None:
    raise ValueError("Image not found or unable to load image")

# print(image.shape)
# print(image.max(), image.min())

# Apply histogram equalization
# image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
# equalized_image = cv2.equalizeHist(image)
image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
clahe = cv2.createCLAHE(clipLimit=40, tileGridSize=(8, 8)) # clipLimit, tileGridSize
equalized_image = clahe.apply(image)
print(equalized_image.max(), equalized_image.min())
# image = image / 255
# equalized_image = exposure.equalize_hist(pp.process(image, [pp.white_balance, pp.clip,pp.gamma]))

# Display the original and equalized images
plt.figure(figsize=(20, 10))

# Original image
plt.subplot(1, 2, 1)
plt.title("Original Image")
plt.imshow(image, cmap='gray')
plt.axis('off')

# Equalized image
plt.subplot(1, 2, 2)
plt.title("Equalized Image")
plt.imshow(equalized_image, cmap='gray')
plt.axis('off')

plt.show()
# Out:
# (526, 1680, 3)
# 255 0
